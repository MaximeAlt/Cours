# %%
import pandas as pd
import numpy as np
import seaborn as sns
from sklearn.linear_model import LinearRegression
from sklearn.model_selection import train_test_split
from sklearn import datasets, linear_model
from sklearn.metrics import mean_squared_error, r2_score, precision_score
import matplotlib.pyplot as plt
from sklearn.impute import SimpleImputer

# %%
df = pd.read_csv("HousingData.csv")
df
# Out:
#         CRIM    ZN  INDUS  CHAS    NOX     RM   AGE     DIS  RAD  TAX  \
# 0    0.00632  18.0   2.31   0.0  0.538  6.575  65.2  4.0900    1  296
# 1    0.02731   0.0   7.07   0.0  0.469  6.421  78.9  4.9671    2  242
# 2    0.02729   0.0   7.07   0.0  0.469  7.185  61.1  4.9671    2  242
# 3    0.03237   0.0   2.18   0.0  0.458  6.998  45.8  6.0622    3  222
# 4    0.06905   0.0   2.18   0.0  0.458  7.147  54.2  6.0622    3  222
# ..       ...   ...    ...   ...    ...    ...   ...     ...  ...  ...
# 501  0.06263   0.0  11.93   0.0  0.573  6.593  69.1  2.4786    1  273
# 502  0.04527   0.0  11.93   0.0  0.573  6.120  76.7  2.2875    1  273
# 503  0.06076   0.0  11.93   0.0  0.573  6.976  91.0  2.1675    1  273
# 504  0.10959   0.0  11.93   0.0  0.573  6.794  89.3  2.3889    1  273
# 505  0.04741   0.0  11.93   0.0  0.573  6.030   NaN  2.5050    1  273
#
#      PTRATIO       B  LSTAT  MEDV
# 0       15.3  396.90   4.98  24.0
# 1       17.8  396.90   9.14  21.6
# ...

# %%
## on supprime les lignes ou le prix est fixé à 50k (données erroné d'après l'énnonceé)

df = df.loc[df["MEDV"] != 50]
df
# Out:
#         CRIM    ZN  INDUS  CHAS    NOX     RM   AGE     DIS  RAD  TAX  \
# 0    0.00632  18.0   2.31   0.0  0.538  6.575  65.2  4.0900    1  296
# 1    0.02731   0.0   7.07   0.0  0.469  6.421  78.9  4.9671    2  242
# 2    0.02729   0.0   7.07   0.0  0.469  7.185  61.1  4.9671    2  242
# 3    0.03237   0.0   2.18   0.0  0.458  6.998  45.8  6.0622    3  222
# 4    0.06905   0.0   2.18   0.0  0.458  7.147  54.2  6.0622    3  222
# ..       ...   ...    ...   ...    ...    ...   ...     ...  ...  ...
# 501  0.06263   0.0  11.93   0.0  0.573  6.593  69.1  2.4786    1  273
# 502  0.04527   0.0  11.93   0.0  0.573  6.120  76.7  2.2875    1  273
# 503  0.06076   0.0  11.93   0.0  0.573  6.976  91.0  2.1675    1  273
# 504  0.10959   0.0  11.93   0.0  0.573  6.794  89.3  2.3889    1  273
# 505  0.04741   0.0  11.93   0.0  0.573  6.030   NaN  2.5050    1  273
#
#      PTRATIO       B  LSTAT  MEDV
# 0       15.3  396.90   4.98  24.0
# 1       17.8  396.90   9.14  21.6
# ...

# %%
np.sum(df.isna())

## CRIM --> taux de criminalité - remplacer nan par la valeur moyenne
## ZN --> propotion de zone résidentielle - remplacer par la valeur moyenne
## INDUS --> proportion d'entrerpise 
## CHAS --> variable binaire (présence ou non de la riviere)


## AGE --> propotion de maison occupé pré années 40 occupé par des proprietaires 
## LSTAT --> proportion de status inférieur dans la populaiton
# Out:
# CRIM       19
# ZN         19
# INDUS      20
# CHAS       20
# NOX         0
# RM          0
# AGE        18
# DIS         0
# RAD         0
# TAX         0
# PTRATIO     0
# B           0
# LSTAT      20
# MEDV        0
# dtype: int64

# %%
## CHAS  :

np.sum(df["CHAS"] == 1) / np.sum(df["CHAS"] == 0)

## 6% des appart sont proche de la riviere
# Out:
# 0.06334841628959276

# %%
df[df["CHAS"] == 1]
# Out:
#         CRIM    ZN  INDUS  CHAS     NOX     RM    AGE     DIS  RAD  TAX  \
# 142  3.32105   0.0  19.58   1.0  0.8710  5.403  100.0  1.3216    5  403
# 154  1.41385   0.0  19.58   1.0  0.8710  6.129   96.0  1.7494    5  403
# 155  3.53501   0.0  19.58   1.0  0.8710  6.152    NaN  1.7455    5  403
# 160  1.27346   0.0  19.58   1.0  0.6050  6.250   92.6  1.7984    5  403
# 208  0.13587   0.0  10.59   1.0  0.4890  6.064   59.1  4.2392    4  277
# 209  0.43571   0.0  10.59   1.0  0.4890  5.344  100.0  3.8750    4  277
# 210  0.17446   NaN  10.59   1.0  0.4890  5.960   92.1  3.8771    4  277
# 211  0.37578   0.0  10.59   1.0  0.4890  5.404   88.6  3.6650    4  277
# 212  0.21719   0.0  10.59   1.0  0.4890  5.807   53.8  3.6526    4  277
# 216  0.04560   0.0  13.89   1.0  0.5500  5.888   56.0  3.1121    5  276
# 218  0.11069   0.0  13.89   1.0  0.5500  5.951   93.8  2.8893    5  276
# 219  0.11425   0.0    NaN   1.0  0.5500  6.373   92.4  3.3633    5  276
# ...

# %%
mean_chas = df[df["CHAS"] == 1].mean()
mean_chas
# Out:
# CRIM         1.456204
# ZN           6.666667
# INDUS       11.741852
# CHAS         1.000000
# NOX          0.584211
# RM           6.410714
# AGE         75.596296
# DIS          3.237614
# RAD          8.500000
# TAX        361.214286
# PTRATIO     17.639286
# B          372.242500
# LSTAT       13.081852
# MEDV        24.289286
# dtype: float64
